# %%
import pandas as pd

var = pd.read_csv("C:\\Users\\XPS\\OneDrive\\Desktop\\Jupyter Notebook\\Pandas\\EV-Data.csv")
var
# Out:
#           region          category           parameter    mode  \
# 0            NaN               NaN                 NaN     NaN
# 1      Australia        Historical      EV sales share    Cars
# 2      Australia               NaN            EV sales     NaN
# 3      Australia        Historical            EV stock    Cars
# 4      Australia        Historical            EV stock    Cars
# ...          ...               ...                 ...     ...
# 12649      World  Projection-STEPS      EV sales share    Cars
# 12650      World  Projection-STEPS      EV stock share    Cars
# 12651      World    Projection-APS  EV charging points      EV
# 12652      World    Projection-APS  EV charging points      EV
# 12653      World  Projection-STEPS      EV stock share  Trucks
#
#                     powertrain    year             unit       value
# 0                          NaN     NaN              NaN         NaN
# 1                           EV  2011.0          percent         NaN
# ...

# %%
var.fillna("EMPTY")
# Out:
#           region          category           parameter    mode  \
# 0          EMPTY             EMPTY               EMPTY   EMPTY
# 1      Australia        Historical      EV sales share    Cars
# 2      Australia             EMPTY            EV sales   EMPTY
# 3      Australia        Historical            EV stock    Cars
# 4      Australia        Historical            EV stock    Cars
# ...          ...               ...                 ...     ...
# 12649      World  Projection-STEPS      EV sales share    Cars
# 12650      World  Projection-STEPS      EV stock share    Cars
# 12651      World    Projection-APS  EV charging points      EV
# 12652      World    Projection-APS  EV charging points      EV
# 12653      World  Projection-STEPS      EV stock share  Trucks
#
#                     powertrain    year             unit       value
# 0                        EMPTY   EMPTY            EMPTY       EMPTY
# 1                           EV  2011.0          percent       EMPTY
# ...

# %%
var.fillna({"parameter":"NULL" , "unit":0 , "year":"0000"})
# Out:
#           region          category           parameter    mode  \
# 0            NaN               NaN                NULL     NaN
# 1      Australia        Historical      EV sales share    Cars
# 2      Australia               NaN            EV sales     NaN
# 3      Australia        Historical            EV stock    Cars
# 4      Australia        Historical            EV stock    Cars
# ...          ...               ...                 ...     ...
# 12649      World  Projection-STEPS      EV sales share    Cars
# 12650      World  Projection-STEPS      EV stock share    Cars
# 12651      World    Projection-APS  EV charging points      EV
# 12652      World    Projection-APS  EV charging points      EV
# 12653      World  Projection-STEPS      EV stock share  Trucks
#
#                     powertrain    year             unit       value
# 0                          NaN    0000                0         NaN
# 1                           EV  2011.0          percent         NaN
# ...

# %%
var.ffill()
# Out:
#           region          category           parameter    mode  \
# 0      Australia        Historical      EV sales share    Cars
# 1      Australia        Historical      EV sales share    Cars
# 2      Australia        Historical            EV sales    Cars
# 3      Australia        Historical            EV stock    Cars
# 4      Australia        Historical            EV stock    Cars
# ...          ...               ...                 ...     ...
# 12649      World  Projection-STEPS      EV sales share    Cars
# 12650      World  Projection-STEPS      EV stock share    Cars
# 12651      World    Projection-APS  EV charging points      EV
# 12652      World    Projection-APS  EV charging points      EV
# 12653      World  Projection-STEPS      EV stock share  Trucks
#
#                     powertrain    year             unit       value
# 0                           EV  2011.0          percent        49.0
# 1                           EV  2011.0          percent        49.0
# ...

# %%
var.bfill()
# Out:
#           region          category           parameter    mode  \
# 0      Australia        Historical      EV sales share    Cars
# 1      Australia        Historical      EV sales share    Cars
# 2      Australia        Historical            EV sales    Cars
# 3      Australia        Historical            EV stock    Cars
# 4      Australia        Historical            EV stock    Cars
# ...          ...               ...                 ...     ...
# 12649      World  Projection-STEPS      EV sales share    Cars
# 12650      World  Projection-STEPS      EV stock share    Cars
# 12651      World    Projection-APS  EV charging points      EV
# 12652      World    Projection-APS  EV charging points      EV
# 12653      World  Projection-STEPS      EV stock share  Trucks
#
#                     powertrain    year             unit       value
# 0                           EV  2011.0          percent        49.0
# 1                           EV  2011.0          percent        49.0
# ...

# %%
var.fillna(10000,inplace=True)
var
# Out:
#           region          category           parameter    mode  \
# 0          10000             10000               10000   10000
# 1      Australia        Historical      EV sales share    Cars
# 2      Australia             10000            EV sales   10000
# 3      Australia        Historical            EV stock    Cars
# 4      Australia        Historical            EV stock    Cars
# ...          ...               ...                 ...     ...
# 12649      World  Projection-STEPS      EV sales share    Cars
# 12650      World  Projection-STEPS      EV stock share    Cars
# 12651      World    Projection-APS  EV charging points      EV
# 12652      World    Projection-APS  EV charging points      EV
# 12653      World  Projection-STEPS      EV stock share  Trucks
#
#                     powertrain     year             unit       value
# 0                        10000  10000.0            10000     10000.0
# 1                           EV   2011.0          percent     10000.0
# ...
