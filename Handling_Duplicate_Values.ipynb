# %%
import pandas as pd

data = pd.read_csv("EV-Data.csv")
data
# Out:
#           region          category           parameter    mode  \
# 0            NaN               NaN                 NaN     NaN
# 1      Australia        Historical      EV sales share    Cars
# 2      Australia               NaN            EV sales     NaN
# 3      Australia        Historical            EV stock    Cars
# 4      Australia        Historical            EV stock    Cars
# ...          ...               ...                 ...     ...
# 12649      World  Projection-STEPS      EV sales share    Cars
# 12650      World  Projection-STEPS      EV stock share    Cars
# 12651      World    Projection-APS  EV charging points      EV
# 12652      World    Projection-APS  EV charging points      EV
# 12653      World  Projection-STEPS      EV stock share  Trucks
#
#                     powertrain    year             unit       value
# 0                          NaN     NaN              NaN         NaN
# 1                           EV  2011.0          percent         NaN
# ...

# %%
print(data.duplicated())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12649    False
# 12650    False
# 12651    False
# 12652    False
# 12653    False
# Length: 12654, dtype: bool

# %%
print(data["parameter"].duplicated().sum())
# Out:
# 12645

# %%
print(data.drop_duplicates("category"))
# Out:
#          region          category           parameter   mode powertrain  \
# 0           NaN               NaN                 NaN    NaN        NaN
# 1     Australia        Historical      EV sales share   Cars         EV
# 1400      China  Projection-STEPS  Electricity demand  Buses         EV
# 1404      China    Projection-APS      EV sales share  Buses         EV
#
#         year     unit    value
# 0        NaN      NaN      NaN
# 1     2011.0  percent      NaN
# 1400  2020.0      GWh  15000.0
# 1404  2020.0  percent     66.0
